# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\nishi\AppData\Local\Temp\ipykernel_20604\3632437423.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
plot_df = pd.read_csv(r'D:\Study\Project\Minor Project\Categories\Automobile\Updated_average_influencers_engagement_automobile.csv')

sns.kdeplot(plot_df, x="Engagement", fill=True)
plt.title('Engagement Ratio of Automobile Category')
plt.xlim(0,2)
# Out:
# (0.0, 2.0)

# %%
plot_df = pd.read_csv(r'D:\Study\Project\Minor Project\Categories\Beverages\Updated_averge_influencers_engagement_beverages.csv')

sns.kdeplot(plot_df, x="Engagement", fill=True)
plt.title('Engagement Ratio of Beverages Category')
plt.xlim(0,2)
# Out:
# (0.0, 2.0)

# %%
plot_df = pd.read_csv(r'D:\Study\Project\Minor Project\Categories\Electronics\Updated_averge_influencers_engagement_electronics.csv')

sns.kdeplot(plot_df, x="Engagement", fill=True)
plt.title('Engagement Ratio of Electronics Category')
plt.xlim(0,4)
# Out:
# (0.0, 4.0)

# %%
plot_df = pd.read_csv(r'D:\Study\Project\Minor Project\Categories\Food\Updated_averge_influencers_engagement_food.csv')

sns.kdeplot(plot_df, x="Engagement", fill=True)
plt.title('Engagement Ratio of Food Category')
plt.xlim(0,2)
# Out:
# (0.0, 2.0)

# %%
plot_df = pd.read_csv(r'D:\Study\Project\Minor Project\Categories\Jewellery\Updated_averge_influencers_engagement_jewellery.csv')

sns.kdeplot(plot_df, x="Engagement", fill=True)
plt.title('Engagement Ratio of Jewellery Category')
plt.xlim(0,2)
# Out:
# (0.0, 2.0)

# %%
plot_df = pd.read_csv(r'D:\Study\Project\Minor Project\Categories\Makeup\Updated_averge_influencers_engagement_makeup.csv')

sns.kdeplot(plot_df, x="Engagement", fill=True)
plt.title('Engagement Ratio of Makeup Category')
plt.xlim(0,2)
# Out:
# (0.0, 2.0)

# %%
plot_df = pd.read_csv(r'D:\Study\Project\Minor Project\Categories\Non-profit\Updated_averge_influencers_engagement_nonprofit.csv')

sns.kdeplot(plot_df, x="Engagement", fill=True)
plt.title('Engagement Ratio of Non-Profit Category')
plt.xlim(0,2)
# Out:
# (0.0, 2.0)

# %%
plot_df = pd.read_csv(r'D:\Study\Project\Minor Project\Categories\Shoes\Updated_averge_influencers_engagement_shoes.csv')

sns.kdeplot(plot_df, x="Engagement", fill=True)
plt.title('Engagement Ratio of Shoes Category')
plt.xlim(0,25)
# Out:
# (0.0, 25.0)

# %%
plot_df = pd.read_csv(r'D:\Study\Project\Minor Project\Categories\Entertainment\Updated_averge_influencers_engagement_entertainment.csv')

sns.kdeplot(plot_df, x="Engagement", fill=True)
plt.title('Engagement Ratio of Entertainment Category')
plt.xlim(0,4)
# Out:
# (0.0, 4.0)

# %%
plot_df = pd.read_csv(r'D:\Study\Project\Minor Project\Categories\Clothing\Updated_averge_influencers_engagement_clothing.csv')

sns.kdeplot(plot_df, x="Engagement", fill=True)
plt.title('Engagement Ratio of Clothing Category')
plt.xlim(0,2)
# Out:
# (0.0, 2.0)
